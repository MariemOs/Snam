# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="89fd51a8-ab9a-4bb4-b738-0b262c96425b">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import sklearn

# %%
file="/home/user9/sfpd_total.csv"
data = pd.read_csv(file)
data.head()
# Out:
# /home/user9/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ﻿IncidntNum        Category                      Descript DayOfWeek  \
# 0    100475254         ASSAULT                       BATTERY    Friday
# 1    100475254        WARRANTS                WARRANT ARREST    Friday
# 2    100475254    NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED    Friday
# 3    110914565        WARRANTS                WARRANT ARREST    Friday
# 4     11351210  MISSING PERSON                  FOUND PERSON   Tuesday
#
#          Date   Time PdDistrict      Resolution               Address  \
# 0  08/26/2016  08:00   NORTHERN  ARREST, BOOKED   UNION ST / GOUGH ST
# 1  08/26/2016  08:00   NORTHERN  ARREST, BOOKED   UNION ST / GOUGH ST
# 2  08/26/2016  08:00   NORTHERN  ARREST, BOOKED   UNION ST / GOUGH ST
# 3  05/29/2015  16:42   SOUTHERN  ARREST, BOOKED    BRYANT ST / 8TH ST
# 4  06/14/2016  08:55    BAYVIEW            NONE  1200 Block of 3RD ST
#
#             X             ...               \
# 0 -122.427271             ...
# 1 -122.427271             ...
# 2 -122.427271             ...
# 3 -122.406971             ...
# 4 -122.389518             ...
#
#    Population density (people per square mile) Renter-occupied apartments  \
# 0                                      24005.0                     9928.0
# 1                                      24005.0                     9928.0
# 2                                      24005.0                     9928.0
# 3                                      17630.0                     9496.0
# 4                                          NaN                        NaN
#
#    Residents with income below 50% of the poverty level in 2013 Salary/wage  \
# 0                                                2.5               175447.0
# 1                                                2.5               175447.0
# 2                                                2.5               175447.0
# 3                                               16.0                88432.0
# 4                                                NaN                    NaN
#
#    Some other race population  Two or more races population  Water area  \
# 0                        79.0                         586.0         0.1
# 1                        79.0                         586.0         0.1
# 2                        79.0                         586.0         0.1
# 3                        93.0                         875.0         0.0
# 4                         NaN                           NaN         NaN
#
#    White population  Zip code population in 2000  Zip code population in 2010
# 0           18552.0                      22903.0                      23088.0
# 1           18552.0                      22903.0                      23088.0
# 2           18552.0                      22903.0                      23088.0
# 3           10241.0                      23016.0                      27170.0
# 4               NaN                          NaN                          NaN
#
# [5 rows x 39 columns]
